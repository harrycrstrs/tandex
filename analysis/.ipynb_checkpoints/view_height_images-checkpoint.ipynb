# %%
import xarray as xr
import os
from matplotlib import pyplot as plt
import numpy as np
import glob
from datetime import datetime

# %%
os.chdir('/disk/scratch/local/hcarstairs/')

# %%
files = glob.glob('*.nc')
files
# Out:
# ['TDX_DEM_GAB_SM_ML10_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML10_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML16_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML3_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML3_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML5_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML16_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML10_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML16_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML16_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML10_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML5_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML5_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML3_fT_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_PER_HS_ML3_fF_unwS_H_tiles10_merged.nc',
#  'TDX_DEM_GAB_SM_ML5_fF_unwS_H_tiles10_merged.nc']

# %%
ds = xr.open_dataset('TDX_DEM_GAB_SM_ML10_fT_unwS_H_tiles10_merged.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (lat: 218, lon: 404, t: 13)
# Coordinates:
#   * t                    (t) datetime64[ns] 2019-11-06T17:22:44.597439 ... 2020-02-15T04:57:11.669028
#   * lat                  (lat) float64 -0.128 -0.1281 ... -0.1603 -0.1604
#   * lon                  (lon) float64 12.24 12.24 12.24 ... 12.3 12.3 12.3
# Data variables:
#     metadata             (t) float64 ...
#     localIncidenceAngle  (t, lat, lon) float64 ...
#     crs                  int32 ...
#     height_corrected     (t, lat, lon) float64 ...
#     coh                  (t, lat, lon) float64 ...
#     intensity            (t, lat, lon) float64 ...
#     elevation            (lat, lon) float32 ...
# Attributes:
#     _NCProperties:  version=2,netcdf=4.7.4,hdf5=1.10.6

# %%
for i in range(6):
    print('time = '+str(i))
    for b in ['localIncidenceAngle','height_corrected','coh','intensity']:
        print(b,np.isnan(ds[b].isel(t=i)).sum().values)
    print('........')
# Out:
# time = 0
# localIncidenceAngle 0
# height_corrected 0
# coh 0
# intensity 0
# ........
# time = 1
# localIncidenceAngle 404
# height_corrected 404
# coh 404
# intensity 404
# ........
# time = 2
# localIncidenceAngle 13492
# height_corrected 13492
# coh 13492
# intensity 13492
# ........
# time = 3
# localIncidenceAngle 621
# height_corrected 621
# coh 621
# intensity 621
# ........
# time = 4
# localIncidenceAngle 19072
# height_corrected 19072
# coh 19072
# intensity 19072
# ........
# time = 5
# localIncidenceAngle 404
# height_corrected 404
# coh 404
# intensity 404
# ........

# %%
def plot_height_GAB(file):
    
    ml = file.split('ML')[1].split('_')[0]
    filtered = file.split('_f')[1].split('_')[0]
    
    with xr.open_dataset(file) as ds:
    
        fig,axs = plt.subplots(3,3,figsize=(16,12),sharex=True,sharey=True)
        a=0
        for i in [0,1,3,5,6,7,8,10,11]:
            ds.height_corrected.isel(t=i).plot(ax=axs.reshape(-1)[a],vmin=-10,vmax=10,add_colorbar=False)
            axs.reshape(-1)[a].set_title(np.datetime_as_string(ds.t[i],unit='D'))
            a+=1

        fig.suptitle('Multilooks: '+ml+' Filtered: '+filtered, fontsize=16)

        plt.savefig()

# %%
ds.height_corrected.median(dim=['lat','lon'])[1:].plot()
